# %% [markdown]
# ## Set Up Environment

# %%
import os
import typing
import uuid

import alifedata_phyloinformatics_convert as apc
from Bio import Phylo
from colorclade._biopython_sort_tree import biopython_sort_tree
from hstrat import hstrat
from hstrat import _auxiliary_lib as hstrat_aux
from hsurf import hsurf
from matplotlib import pyplot as plt
from matplotlib import patches as mpl_patches
import numpy as np
import pandas as pd
import tqdist
from tqdm.notebook import tqdm

# %% [markdown]
# ## Configure Experiment

# %% [markdown]
# Set up random number generator. (Do not edit.)

# %%
seed = 1

seed
# Out:
# 1

# %%
from hstrat._auxiliary_lib import seed_random

seed_random(seed)

# %% [markdown]
# Helper functions.

# %%
from pylib._phyloviz import (
    logify_phylo,
    make_policy,
    make_reconstructed_rosettatree,
    prune_100,
    plot2,
    calc_tqdist_distance,
)

# %% [markdown]
# ## Generate Phylogeny
#
# Use simple evolutionary simulation to generate a phylogenetic history to test reconstruction process on.

# %%
num_generations = 100000

# %%
true_phylogeny_df = pd.read_parquet("https://osf.io/zbwme/download")

# %%
full_true_phylogeny_df = true_phylogeny_df.copy()

# %% [markdown]
# ## Downsample Phylogeny

# %%
downsample = 500
print(f"{downsample=}")
if downsample:
    print(f"downsampling to {downsample=}")
    leaf_ids = hstrat_aux.alifestd_find_leaf_ids(true_phylogeny_df)
    downsample_ids = np.random.default_rng(seed).choice(
        leaf_ids,
        downsample,
        replace=False,
    )
    true_phylogeny_df["extant"] = False
    true_phylogeny_df.loc[
        true_phylogeny_df["id"].isin(downsample_ids),
        "extant",
    ] = True
    true_phylogeny_df = hstrat_aux.alifestd_prune_extinct_lineages_asexual(
        true_phylogeny_df,
        mutate=True,
    )
    assert (
        len(hstrat_aux.alifestd_find_leaf_ids(true_phylogeny_df)) == downsample
    )

    true_phylogeny_df = hstrat_aux.alifestd_collapse_unifurcations(
        true_phylogeny_df,
        mutate=True,
    )
    true_phylogeny_df = hstrat_aux.alifestd_to_working_format(
        true_phylogeny_df,
        mutate=True,
    ).reset_index(drop=True)
# Out:
# downsample=500
# downsampling to downsample=500

# %% [markdown]
# ## Generate Reconstruction
#
# Generate genome annotations as if tracking phylogeny in distributed environment.
# Then run reconstruction proess to estimate true phylogeny from generated annotations.

# %%
trees = [
    make_reconstructed_rosettatree(
        "surf-tilted",
        annotation_size_bits=32,
        differentia_width_bits=1,
        true_phylogeny_df=true_phylogeny_df,
        num_generations=num_generations,
    ),
    make_reconstructed_rosettatree(
        "surf-tilted",
        annotation_size_bits=64,
        differentia_width_bits=1,
        true_phylogeny_df=true_phylogeny_df,
        num_generations=num_generations,
    ),
    make_reconstructed_rosettatree(
        "surf-tilted",
        annotation_size_bits=256,
        differentia_width_bits=1,
        true_phylogeny_df=true_phylogeny_df,
        num_generations=num_generations,
    ),
    make_reconstructed_rosettatree(
        "surf-tilted",
        annotation_size_bits=256,
        differentia_width_bits=8,
        true_phylogeny_df=true_phylogeny_df,
        num_generations=num_generations,
    ),
]
fig, (axs1, axs2) = plt.subplots(
    2, 4, gridspec_kw={"wspace": 0, "hspace": 0.1}, height_ratios=[1, 3]
)
fig.set_size_inches(10, 8)

plot2(apc.RosettaTree(logify_phylo(true_phylogeny_df)), trees[0], seed, axs2[0])
plot2(apc.RosettaTree(logify_phylo(true_phylogeny_df)), trees[1], seed, axs2[1])
plot2(apc.RosettaTree(logify_phylo(true_phylogeny_df)), trees[2], seed, axs2[2])
plot2(apc.RosettaTree(logify_phylo(true_phylogeny_df)), trees[3], seed, axs2[3])

plt.tight_layout()
plt.subplots_adjust(wspace=0, hspace=0)

# Create the legend patches
orange_patch = mpl_patches.Patch(color="orange", label="Reference")
blue_patch = mpl_patches.Patch(color="blue", label="Reconstruction")

# Create a custom legend without a frame
legend = fig.legend(
    handles=[orange_patch, blue_patch],
    loc="lower center",
    ncol=2,
    frameon=False,
)

axs1[0].set_title("32-bit size\nbit differentia")
axs1[1].set_title("64-bit size,\nbit differentia")
axs1[2].set_title("256-bit size\nbit differentia")
axs1[3].set_title("256-bit size\nbyte differentia")
# Remove axes borders except for bottom, and remove y-axis tick/labels
for i, ax in enumerate(axs1):
    ax.axes.get_xaxis().set_visible(True)
    ax.axes.get_yaxis().set_visible(True)
    ax.set_xticks([0.33, 0.66])
    ax.set_xticklabels(["T. Dist.", "I.N. Loss"])
    ax.spines["top"].set_visible(False)
    ax.spines["bottom"].set_visible(True)
    ax.spines["right"].set_visible(False)
    ax.spines["left"].set_visible(True)
    if i:
        ax.set_yticklabels([])

for tree, ax in zip(trees, axs1):
    tripdist = calc_tqdist_distance(true_phylogeny_df, tree.as_alife)[
        "triplet_distance"
    ]
    # tripdist = hstrat_aux.alifestd_estimate_triplet_distance_asexual(
    #     hstrat_aux.alifestd_collapse_unifurcations(true_phylogeny_df),
    #     hstrat_aux.alifestd_collapse_unifurcations(tree.as_alife),
    #     taxon_label_key="taxon_label",
    #     strict=True,
    #     progress_wrap=tqdm,
    #     mutate=False,
    #     confidence=0.9,
    #     precision=0.05,
    # )
    innernodeloss = 1 - hstrat_aux.alifestd_count_inner_nodes(
        hstrat_aux.alifestd_collapse_unifurcations(tree.as_alife),
    ) / hstrat_aux.alifestd_count_inner_nodes(
        hstrat_aux.alifestd_collapse_unifurcations(true_phylogeny_df),
    )
    ax.set_xlim(0, 1)
    ax.set_ylim(-0.2, 1)
    ax.axhline(y=0, color="black", linewidth=1)
    ax.grid(axis="y")
    ax.scatter(
        [0.33],
        [tripdist],
        color=["purple"],
        marker="o",
        clip_on=False,
        s=80,
        zorder=10,
    )
    ax.scatter(
        [0.66],
        [innernodeloss],
        color=["green"],
        marker="v",
        clip_on=False,
        s=80,
        zorder=10,
    )


# Adjust layout
plt.subplots_adjust(bottom=0.05, top=0.86)

fig.suptitle("policy = tilted (surface)", size="xx-large")
os.makedirs("outplots", exist_ok=True)
plt.savefig(
    "outplots/a=examplepanel+policy=surf-tilted+regime=plain+ext=.pdf",
    bbox_inches="tight",
)
# Out:
# annotation_capacity_strata=32
#   0%|          | 0/950 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# annotation_capacity_strata=64
#   0%|          | 0/950 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# annotation_capacity_strata=256
#   0%|          | 0/950 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# annotation_capacity_strata=32
#   0%|          | 0/950 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# /tmp/ipykernel_5915/1548109125.py:41: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
trees = [
    make_reconstructed_rosettatree(
        "col-steady",
        annotation_size_bits=32,
        differentia_width_bits=1,
        true_phylogeny_df=true_phylogeny_df,
        num_generations=num_generations,
    ),
    make_reconstructed_rosettatree(
        "col-steady",
        annotation_size_bits=64,
        differentia_width_bits=1,
        true_phylogeny_df=true_phylogeny_df,
        num_generations=num_generations,
    ),
    make_reconstructed_rosettatree(
        "col-steady",
        annotation_size_bits=256,
        differentia_width_bits=1,
        true_phylogeny_df=true_phylogeny_df,
        num_generations=num_generations,
    ),
    make_reconstructed_rosettatree(
        "col-steady",
        annotation_size_bits=256,
        differentia_width_bits=8,
        true_phylogeny_df=true_phylogeny_df,
        num_generations=num_generations,
    ),
]
fig, (axs1, axs2) = plt.subplots(
    2, 4, gridspec_kw={"wspace": 0, "hspace": 0.1}, height_ratios=[1, 3]
)
fig.set_size_inches(10, 8)

plot2(apc.RosettaTree(logify_phylo(true_phylogeny_df)), trees[0], seed, axs2[0])
plot2(apc.RosettaTree(logify_phylo(true_phylogeny_df)), trees[1], seed, axs2[1])
plot2(apc.RosettaTree(logify_phylo(true_phylogeny_df)), trees[2], seed, axs2[2])
plot2(apc.RosettaTree(logify_phylo(true_phylogeny_df)), trees[3], seed, axs2[3])

plt.tight_layout()
plt.subplots_adjust(wspace=0, hspace=0)

# Create the legend patches
orange_patch = mpl_patches.Patch(color="orange", label="Reference")
blue_patch = mpl_patches.Patch(color="blue", label="Reconstruction")

# Create a custom legend without a frame
legend = fig.legend(
    handles=[orange_patch, blue_patch],
    loc="lower center",
    ncol=2,
    frameon=False,
)

axs1[0].set_title("32-bit size\nbit differentia")
axs1[1].set_title("64-bit size,\nbit differentia")
axs1[2].set_title("256-bit size\nbit differentia")
axs1[3].set_title("256-bit size\nbyte differentia")
# Remove axes borders except for bottom, and remove y-axis tick/labels
for i, ax in enumerate(axs1):
    ax.axes.get_xaxis().set_visible(True)
    ax.axes.get_yaxis().set_visible(True)
    ax.set_xticks([0.33, 0.66])
    ax.set_xticklabels(["T. Dist.", "I.N. Loss"])
    ax.spines["top"].set_visible(False)
    ax.spines["bottom"].set_visible(True)
    ax.spines["right"].set_visible(False)
    ax.spines["left"].set_visible(True)
    if i:
        ax.set_yticklabels([])

for tree, ax in zip(trees, axs1):
    tripdist = calc_tqdist_distance(true_phylogeny_df, tree.as_alife)[
        "triplet_distance"
    ]
    # tripdist = hstrat_aux.alifestd_estimate_triplet_distance_asexual(
    #     hstrat_aux.alifestd_collapse_unifurcations(true_phylogeny_df),
    #     hstrat_aux.alifestd_collapse_unifurcations(tree.as_alife),
    #     taxon_label_key="taxon_label",
    #     strict=True,
    #     progress_wrap=tqdm,
    #     mutate=False,
    #     confidence=0.9,
    #     precision=0.05,
    # )
    innernodeloss = 1 - hstrat_aux.alifestd_count_inner_nodes(
        hstrat_aux.alifestd_collapse_unifurcations(tree.as_alife),
    ) / hstrat_aux.alifestd_count_inner_nodes(
        hstrat_aux.alifestd_collapse_unifurcations(true_phylogeny_df),
    )
    ax.set_xlim(0, 1)
    ax.set_ylim(-0.2, 1)
    ax.axhline(y=0, color="black", linewidth=1)
    ax.grid(axis="y")
    ax.scatter(
        [0.33],
        [tripdist],
        color=["purple"],
        marker="o",
        clip_on=False,
        s=80,
        zorder=10,
    )
    ax.scatter(
        [0.66],
        [innernodeloss],
        color=["green"],
        marker="v",
        clip_on=False,
        s=80,
        zorder=10,
    )


# Adjust layout
plt.subplots_adjust(bottom=0.05, top=0.86)

fig.suptitle("policy = steady (column)", size="xx-large")
os.makedirs("outplots", exist_ok=True)
plt.savefig(
    "outplots/a=examplepanel+policy=col-steady+regime=plain+ext=.pdf",
    bbox_inches="tight",
)
# Out:
# annotation_capacity_strata=32
#   0%|          | 0/950 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# annotation_capacity_strata=64
#   0%|          | 0/950 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# annotation_capacity_strata=256
#   0%|          | 0/950 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# annotation_capacity_strata=32
#   0%|          | 0/950 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# /tmp/ipykernel_5915/1040035600.py:41: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %% [markdown]
# ## Reproducibility Information
#
# For future reference if reproducing experiments.

# %%
import datetime

datetime.datetime.now().isoformat()
# Out:
# '2024-10-02T04:02:38.405389'

# %%
# %load_ext watermark
# %watermark
# Out:
# Last updated: 2024-10-02T04:02:38.415063+00:00
#
# Python implementation: CPython
# Python version       : 3.10.12
# IPython version      : 8.22.1
#
# Compiler    : GCC 11.4.0
# OS          : Linux
# Release     : 6.8.0-1014-azure
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 4
# Architecture: 64bit

# %%
locals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'import os\nimport typing\nimport uuid\n\nimport alifedata_phyloinformatics_convert as apc\nfrom Bio import Phylo\nfrom colorclade._biopython_sort_tree import biopython_sort_tree\nfrom hstrat import hstrat\nfrom hstrat import _auxiliary_lib as hstrat_aux\nfrom hsurf import hsurf\nfrom matplotlib import pyplot as plt\nfrom matplotlib import patches as mpl_patches\nimport numpy as np\nimport pandas as pd\nimport tqdist\nfrom tqdm.notebook import tqdm',
#   'seed = 1\n\nseed',
#   'from hstrat._auxiliary_lib import seed_random\n\nseed_random(seed)',
#   'from pylib._phyloviz import (\n    logify_phylo,\n    make_policy,\n    make_reconstructed_rosettatree,\n    prune_100,\n    plot2,\n    calc_tqdist_distance,\n)',
#   'num_generations = 100000',
#   'true_phylogeny_df = pd.read_parquet("https://osf.io/zbwme/download")',
#   'full_true_phylogeny_df = true_phylogeny_df.copy()',
#   'downsample = 500\nprint(f"{downsample=}")\nif downsample:\n    print(f"downsampling to {downsample=}")\n    leaf_ids = hstrat_aux.alifestd_find_leaf_ids(true_phylogeny_df)\n    downsample_ids = np.random.default_rng(seed).choice(\n        leaf_ids,\n        downsample,\n        replace=False,\n    )\n    true_phylogeny_df["extant"] = False\n    true_phylogeny_df.loc[\n        true_phylogeny_df["id"].isin(downsample_ids),\n        "extant",\n    ] = True\n    true_phylogeny_df = hstrat_aux.alifestd_prune_extinct_lineages_asexual(\n        true_phylogeny_df,\n        mutate=True,\n    )\n    assert (\n        len(hstrat_aux.alifestd_find_leaf_ids(true_phylogeny_df)) == downsample\n    )\n\n    true_phylogeny_df = hstrat_aux.alifestd_collapse_unifurcations(\n        true_phylogeny_df,\n        mutate=True,\n    )\n    true_phylogeny_df = hstrat_aux.alifestd_to_working_format(\n        true_phylogeny_df,\n        mutate=True,\n    ).reset_index(drop=True)',
#   'trees = [\n    make_reconstructed_rosettatree(\n        "surf-tilted",\n        annotation_size_bits=32,\n        differentia_width_bits=1,\n        true_phylogeny_df=true_phylogeny_df,\n        num_generations=num_generations,\n    ),\n    make_reconstructed_rosettatree(\n        "surf-tilted",\n        annotation_size_bits=64,\n        differentia_width_bits=1,\n        true_phylogeny_df=true_phylogeny_df,\n        num_generations=num_generations,\n    ),\n    make_reconstructed_rosettatree(\n        "surf-tilted",\n        annotation_size_bits=256,\n        differentia_width_bits=1,\n        true_phylogeny_df=true_phylogeny_df,\n        num_generations=num_generations,\n    ),\n    make_reconstructed_rosettatree(\n        "surf-tilted",\n        annotation_size_bits=256,\n        differentia_width_bits=8,\n        true_phylogeny_df=true_phylogeny_df,\n        num_generations=num_generations,\n    ),\n]\nfig, (axs1, axs2) = plt.subplots(\n    2, 4, gridspec_kw={"wspace": 0, "hspace": 0.1}, height_ratios=[1, 3]\n)\nfig.set_size_inches(10, 8)\n\nplot2(apc.RosettaTree(logify_phylo(true_phylogeny_df)), trees[0], seed, axs2[0])\nplot2(apc.RosettaTree(logify_phylo(true_phylogeny_df)), trees[1], seed, axs2[1])\nplot2(apc.RosettaTree(logify_phylo(true_phylogeny_df)), trees[2], seed, axs2[2])\nplot2(apc.RosettaTree(logify_phylo(true_phylogeny_df)), trees[3], seed, axs2[3])\n\nplt.tight_layout()\nplt.subplots_adjust(wspace=0, hspace=0)\n\n# Create the legend patches\norange_patch = mpl_patches.Patch(color="orange", label="Reference")\nblue_patch = mpl_patches.Patch(color="blue", label="Reconstruction")\n\n# Create a custom legend without a frame\nlegend = fig.legend(\n    handles=[orange_patch, blue_patch],\n    loc="lower center",\n    ncol=2,\n    frameon=False,\n)\n\naxs1[0].set_title("32-bit size\\nbit differentia")\naxs1[1].set_title("64-bit size,\\nbit differentia")\naxs1[2].set_title("256-bit size\\nbit differentia")\naxs1[3].set_title("256-bit size\\nbyte differentia")\n# Remove axes borders except for bottom, and remove y-axis tick/labels\nfor i, ax in enumerate(axs1):\n    ax.axes.get_xaxis().set_visible(True)\n    ax.axes.get_yaxis().set_visible(True)\n    ax.set_xticks([0.33, 0.66])\n    ax.set_xticklabels(["T. Dist.", "I.N. Loss"])\n    ax.spines["top"].set_visible(False)\n    ax.spines["bottom"].set_visible(True)\n    ax.spines["right"].set_visible(False)\n    ax.spines["left"].set_visible(True)\n    if i:\n        ax.set_yticklabels([])\n\nfor tree, ax in zip(trees, axs1):\n    tripdist = calc_tqdist_distance(true_phylogeny_df, tree.as_alife)[\n        "triplet_distance"\n    ]\n    # tripdist = hstrat_aux.alifestd_estimate_triplet_distance_asexual(\n    #     hstrat_aux.alifestd_collapse_unifurcations(true_phylogeny_df),\n    #     hstrat_aux.alifestd_collapse_unifurcations(tree.as_alife),\n    #     taxon_label_key="taxon_label",\n    #     strict=True,\n    #     progress_wrap=tqdm,\n    #     mutate=False,\n    #     confidence=0.9,\n    #     precision=0.05,\n    # )\n    innernodeloss = 1 - hstrat_aux.alifestd_count_inner_nodes(\n        hstrat_aux.alifestd_collapse_unifurcations(tree.as_alife),\n    ) / hstrat_aux.alifestd_count_inner_nodes(\n        hstrat_aux.alifestd_collapse_unifurcations(true_phylogeny_df),\n    )\n    ax.set_xlim(0, 1)\n    ax.set_ylim(-0.2, 1)\n    ax.axhline(y=0, color="black", linewidth=1)\n    ax.grid(axis="y")\n    ax.scatter(\n        [0.33],\n        [tripdist],\n        color=["purple"],\n        marker="o",\n        clip_on=False,\n        s=80,\n        zorder=10,\n    )\n    ax.scatter(\n        [0.66],\n        [innernodeloss],\n        color=["green"],\n        marker="v",\n        clip_on=False,\n        s=80,\n        zorder=10,\n    )\n\n\n# Adjust layout\nplt.subplots_adjust(bottom=0.05, top=0.86)\n\nfig.suptitle("policy = tilted (surface)", size="xx-large")\nos.makedirs("outplots", exist_ok=True)\nplt.savefig(\n    "outplots/a=examplepanel+policy=surf-tilted+regime=plai ...
#   'trees = [\n    make_reconstructed_rosettatree(\n        "col-steady",\n        annotation_size_bits=32,\n        differentia_width_bits=1,\n        true_phylogeny_df=true_phylogeny_df,\n        num_generations=num_generations,\n    ),\n    make_reconstructed_rosettatree(\n        "col-steady",\n        annotation_size_bits=64,\n        differentia_width_bits=1,\n        true_phylogeny_df=true_phylogeny_df,\n        num_generations=num_generations,\n    ),\n    make_reconstructed_rosettatree(\n        "col-steady",\n        annotation_size_bits=256,\n        differentia_width_bits=1,\n        true_phylogeny_df=true_phylogeny_df,\n        num_generations=num_generations,\n    ),\n    make_reconstructed_rosettatree(\n        "col-steady",\n        annotation_size_bits=256,\n        differentia_width_bits=8,\n        true_phylogeny_df=true_phylogeny_df,\n        num_generations=num_generations,\n    ),\n]\nfig, (axs1, axs2) = plt.subplots(\n    2, 4, gridspec_kw={"wspace": 0, "hspace": 0.1}, height_ratios=[1, 3]\n)\nfig.set_size_inches(10, 8)\n\nplot2(apc.RosettaTree(logify_phylo(true_phylogeny_df)), trees[0], seed, axs2[0])\nplot2(apc.RosettaTree(logify_phylo(true_phylogeny_df)), trees[1], seed, axs2[1])\nplot2(apc.RosettaTree(logify_phylo(true_phylogeny_df)), trees[2], seed, axs2[2])\nplot2(apc.RosettaTree(logify_phylo(true_phylogeny_df)), trees[3], seed, axs2[3])\n\nplt.tight_layout()\nplt.subplots_adjust(wspace=0, hspace=0)\n\n# Create the legend patches\norange_patch = mpl_patches.Patch(color="orange", label="Reference")\nblue_patch = mpl_patches.Patch(color="blue", label="Reconstruction")\n\n# Create a custom legend without a frame\nlegend = fig.legend(\n    handles=[orange_patch, blue_patch],\n    loc="lower center",\n    ncol=2,\n    frameon=False,\n)\n\naxs1[0].set_title("32-bit size\\nbit differentia")\naxs1[1].set_title("64-bit size,\\nbit differentia")\naxs1[2].set_title("256-bit size\\nbit differentia")\naxs1[3].set_title("256-bit size\\nbyte differentia")\n# Remove axes borders except for bottom, and remove y-axis tick/labels\nfor i, ax in enumerate(axs1):\n    ax.axes.get_xaxis().set_visible(True)\n    ax.axes.get_yaxis().set_visible(True)\n    ax.set_xticks([0.33, 0.66])\n    ax.set_xticklabels(["T. Dist.", "I.N. Loss"])\n    ax.spines["top"].set_visible(False)\n    ax.spines["bottom"].set_visible(True)\n    ax.spines["right"].set_visible(False)\n    ax.spines["left"].set_visible(True)\n    if i:\n        ax.set_yticklabels([])\n\nfor tree, ax in zip(trees, axs1):\n    tripdist = calc_tqdist_distance(true_phylogeny_df, tree.as_alife)[\n        "triplet_distance"\n    ]\n    # tripdist = hstrat_aux.alifestd_estimate_triplet_distance_asexual(\n    #     hstrat_aux.alifestd_collapse_unifurcations(true_phylogeny_df),\n    #     hstrat_aux.alifestd_collapse_unifurcations(tree.as_alife),\n    #     taxon_label_key="taxon_label",\n    #     strict=True,\n    #     progress_wrap=tqdm,\n    #     mutate=False,\n    #     confidence=0.9,\n    #     precision=0.05,\n    # )\n    innernodeloss = 1 - hstrat_aux.alifestd_count_inner_nodes(\n        hstrat_aux.alifestd_collapse_unifurcations(tree.as_alife),\n    ) / hstrat_aux.alifestd_count_inner_nodes(\n        hstrat_aux.alifestd_collapse_unifurcations(true_phylogeny_df),\n    )\n    ax.set_xlim(0, 1)\n    ax.set_ylim(-0.2, 1)\n    ax.axhline(y=0, color="black", linewidth=1)\n    ax.grid(axis="y")\n    ax.scatter(\n        [0.33],\n        [tripdist],\n        color=["purple"],\n        marker="o",\n        clip_on=False,\n        s=80,\n        zorder=10,\n    )\n    ax.scatter(\n        [0.66],\n        [innernodeloss],\n        color=["green"],\n        marker="v",\n        clip_on=False,\n        s=80,\n        zorder=10,\n    )\n\n\n# Adjust layout\nplt.subplots_adjust(bottom=0.05, top=0.86)\n\nfig.suptitle("policy = steady (column)", size="xx-large")\nos.makedirs("outplots", exist_ok=True)\nplt.savefig(\n    "outplots/a=examplepanel+policy=col-steady+regime=plain+ext= ...
#   'import datetime\n\ndatetime.datetime.now().isoformat()',
#   "get_ipython().run_line_magic('load_ext', 'watermark')\nget_ipython().run_line_magic('watermark', '')",
#   'locals()'],
#  '_oh': {2: 1, 11: '2024-10-02T04:02:38.405389'},
#  '_dh': [PosixPath('/home/runner/work/hstrat-reconstruction-quality/hstrat-reconstruction-quality/binder')],
#  'In': ['',
#   'import os\nimport typing\nimport uuid\n\nimport alifedata_phyloinformatics_convert as apc\nfrom Bio import Phylo\nfrom colorclade._biopython_sort_tree import biopython_sort_tree\nfrom hstrat import hstrat\nfrom hstrat import _auxiliary_lib as hstrat_aux\nfrom hsurf import hsurf\nfrom matplotlib import pyplot as plt\nfrom matplotlib import patches as mpl_patches\nimport numpy as np\nimport pandas as pd\nimport tqdist\nfrom tqdm.notebook import tqdm',
#   'seed = 1\n\nseed',
#   'from hstrat._auxiliary_lib import seed_random\n\nseed_random(seed)',
#   'from pylib._phyloviz import (\n    logify_phylo,\n    make_policy,\n    make_reconstructed_rosettatree,\n    prune_100,\n    plot2,\n    calc_tqdist_distance,\n)',
#   'num_generations = 100000',
#   'true_phylogeny_df = pd.read_parquet("https://osf.io/zbwme/download")',
#   'full_true_phylogeny_df = true_phylogeny_df.copy()',
#   'downsample = 500\nprint(f"{downsample=}")\nif downsample:\n    print(f"downsampling to {downsample=}")\n    leaf_ids = hstrat_aux.alifestd_find_leaf_ids(true_phylogeny_df)\n    downsample_ids = np.random.default_rng(seed).choice(\n        leaf_ids,\n        downsample,\n        replace=False,\n    )\n    true_phylogeny_df["extant"] = False\n    true_phylogeny_df.loc[\n        true_phylogeny_df["id"].isin(downsample_ids),\n        "extant",\n    ] = True\n    true_phylogeny_df = hstrat_aux.alifestd_prune_extinct_lineages_asexual(\n        true_phylogeny_df,\n        mutate=True,\n    )\n    assert (\n        len(hstrat_aux.alifestd_find_leaf_ids(true_phylogeny_df)) == downsample\n    )\n\n    true_phylogeny_df = hstrat_aux.alifestd_collapse_unifurcations(\n        true_phylogeny_df,\n        mutate=True,\n    )\n    true_phylogeny_df = hstrat_aux.alifestd_to_working_format(\n        true_phylogeny_df,\n        mutate=True,\n    ).reset_index(drop=True)',
#   'trees = [\n    make_reconstructed_rosettatree(\n        "surf-tilted",\n        annotation_size_bits=32,\n        differentia_width_bits=1,\n        true_phylogeny_df=true_phylogeny_df,\n        num_generations=num_generations,\n    ),\n    make_reconstructed_rosettatree(\n        "surf-tilted",\n        annotation_size_bits=64,\n        differentia_width_bits=1,\n        true_phylogeny_df=true_phylogeny_df,\n        num_generations=num_generations,\n    ),\n    make_reconstructed_rosettatree(\n        "surf-tilted",\n        annotation_size_bits=256,\n        differentia_width_bits=1,\n        true_phylogeny_df=true_phylogeny_df,\n        num_generations=num_generations,\n    ),\n    make_reconstructed_rosettatree(\n        "surf-tilted",\n        annotation_size_bits=256,\n        differentia_width_bits=8,\n        true_phylogeny_df=true_phylogeny_df,\n        num_generations=num_generations,\n    ),\n]\nfig, (axs1, axs2) = plt.subplots(\n    2, 4, gridspec_kw={"wspace": 0, "hspace": 0.1}, height_ratios=[1, 3]\n)\nfig.set_size_inches(10, 8)\n\nplot2(apc.RosettaTree(logify_phylo(true_phylogeny_df)), trees[0], seed, axs2[0])\nplot2(apc.RosettaTree(logify_phylo(true_phylogeny_df)), trees[1], seed, axs2[1])\nplot2(apc.RosettaTree(logify_phylo(true_phylogeny_df)), trees[2], seed, axs2[2])\nplot2(apc.RosettaTree(logify_phylo(true_phylogeny_df)), trees[3], seed, axs2[3])\n\nplt.tight_layout()\nplt.subplots_adjust(wspace=0, hspace=0)\n\n# Create the legend patches\norange_patch = mpl_patches.Patch(color="orange", label="Reference")\nblue_patch = mpl_patches.Patch(color="blue", label="Reconstruction")\n\n# Create a custom legend without a frame\nlegend = fig.legend(\n    handles=[orange_patch, blue_patch],\n    loc="lower center",\n    ncol=2,\n    frameon=False,\n)\n\naxs1[0].set_title("32-bit size\\nbit differentia")\naxs1[1].set_title("64-bit size,\\nbit differentia")\naxs1[2].set_title("256-bit size\\nbit differentia")\naxs1[3].set_title("256-bit size\\nbyte differentia")\n# Remove axes borders except for bottom, and remove y-axis tick/labels\nfor i, ax in enumerate(axs1):\n    ax.axes.get_xaxis().set_visible(True)\n    ax.axes.get_yaxis().set_visible(True)\n    ax.set_xticks([0.33, 0.66])\n    ax.set_xticklabels(["T. Dist.", "I.N. Loss"])\n    ax.spines["top"].set_visible(False)\n    ax.spines["bottom"].set_visible(True)\n    ax.spines["right"].set_visible(False)\n    ax.spines["left"].set_visible(True)\n    if i:\n        ax.set_yticklabels([])\n\nfor tree, ax in zip(trees, axs1):\n    tripdist = calc_tqdist_distance(true_phylogeny_df, tree.as_alife)[\n        "triplet_distance"\n    ]\n    # tripdist = hstrat_aux.alifestd_estimate_triplet_distance_asexual(\n    #     hstrat_aux.alifestd_collapse_unifurcations(true_phylogeny_df),\n    #     hstrat_aux.alifestd_collapse_unifurcations(tree.as_alife),\n    #     taxon_label_key="taxon_label",\n    #     strict=True,\n    #     progress_wrap=tqdm,\n    #     mutate=False,\n    #     confidence=0.9,\n    #     precision=0.05,\n    # )\n    innernodeloss = 1 - hstrat_aux.alifestd_count_inner_nodes(\n        hstrat_aux.alifestd_collapse_unifurcations(tree.as_alife),\n    ) / hstrat_aux.alifestd_count_inner_nodes(\n        hstrat_aux.alifestd_collapse_unifurcations(true_phylogeny_df),\n    )\n    ax.set_xlim(0, 1)\n    ax.set_ylim(-0.2, 1)\n    ax.axhline(y=0, color="black", linewidth=1)\n    ax.grid(axis="y")\n    ax.scatter(\n        [0.33],\n        [tripdist],\n        color=["purple"],\n        marker="o",\n        clip_on=False,\n        s=80,\n        zorder=10,\n    )\n    ax.scatter(\n        [0.66],\n        [innernodeloss],\n        color=["green"],\n        marker="v",\n        clip_on=False,\n        s=80,\n        zorder=10,\n    )\n\n\n# Adjust layout\nplt.subplots_adjust(bottom=0.05, top=0.86)\n\nfig.suptitle("policy = tilted (surface)", size="xx-large")\nos.makedirs("outplots", exist_ok=True)\nplt.savefig(\n    "outplots/a=examplepanel+policy=surf-tilted+regime=plai ...
#   'trees = [\n    make_reconstructed_rosettatree(\n        "col-steady",\n        annotation_size_bits=32,\n        differentia_width_bits=1,\n        true_phylogeny_df=true_phylogeny_df,\n        num_generations=num_generations,\n    ),\n    make_reconstructed_rosettatree(\n        "col-steady",\n        annotation_size_bits=64,\n        differentia_width_bits=1,\n        true_phylogeny_df=true_phylogeny_df,\n        num_generations=num_generations,\n    ),\n    make_reconstructed_rosettatree(\n        "col-steady",\n        annotation_size_bits=256,\n        differentia_width_bits=1,\n        true_phylogeny_df=true_phylogeny_df,\n        num_generations=num_generations,\n    ),\n    make_reconstructed_rosettatree(\n        "col-steady",\n        annotation_size_bits=256,\n        differentia_width_bits=8,\n        true_phylogeny_df=true_phylogeny_df,\n        num_generations=num_generations,\n    ),\n]\nfig, (axs1, axs2) = plt.subplots(\n    2, 4, gridspec_kw={"wspace": 0, "hspace": 0.1}, height_ratios=[1, 3]\n)\nfig.set_size_inches(10, 8)\n\nplot2(apc.RosettaTree(logify_phylo(true_phylogeny_df)), trees[0], seed, axs2[0])\nplot2(apc.RosettaTree(logify_phylo(true_phylogeny_df)), trees[1], seed, axs2[1])\nplot2(apc.RosettaTree(logify_phylo(true_phylogeny_df)), trees[2], seed, axs2[2])\nplot2(apc.RosettaTree(logify_phylo(true_phylogeny_df)), trees[3], seed, axs2[3])\n\nplt.tight_layout()\nplt.subplots_adjust(wspace=0, hspace=0)\n\n# Create the legend patches\norange_patch = mpl_patches.Patch(color="orange", label="Reference")\nblue_patch = mpl_patches.Patch(color="blue", label="Reconstruction")\n\n# Create a custom legend without a frame\nlegend = fig.legend(\n    handles=[orange_patch, blue_patch],\n    loc="lower center",\n    ncol=2,\n    frameon=False,\n)\n\naxs1[0].set_title("32-bit size\\nbit differentia")\naxs1[1].set_title("64-bit size,\\nbit differentia")\naxs1[2].set_title("256-bit size\\nbit differentia")\naxs1[3].set_title("256-bit size\\nbyte differentia")\n# Remove axes borders except for bottom, and remove y-axis tick/labels\nfor i, ax in enumerate(axs1):\n    ax.axes.get_xaxis().set_visible(True)\n    ax.axes.get_yaxis().set_visible(True)\n    ax.set_xticks([0.33, 0.66])\n    ax.set_xticklabels(["T. Dist.", "I.N. Loss"])\n    ax.spines["top"].set_visible(False)\n    ax.spines["bottom"].set_visible(True)\n    ax.spines["right"].set_visible(False)\n    ax.spines["left"].set_visible(True)\n    if i:\n        ax.set_yticklabels([])\n\nfor tree, ax in zip(trees, axs1):\n    tripdist = calc_tqdist_distance(true_phylogeny_df, tree.as_alife)[\n        "triplet_distance"\n    ]\n    # tripdist = hstrat_aux.alifestd_estimate_triplet_distance_asexual(\n    #     hstrat_aux.alifestd_collapse_unifurcations(true_phylogeny_df),\n    #     hstrat_aux.alifestd_collapse_unifurcations(tree.as_alife),\n    #     taxon_label_key="taxon_label",\n    #     strict=True,\n    #     progress_wrap=tqdm,\n    #     mutate=False,\n    #     confidence=0.9,\n    #     precision=0.05,\n    # )\n    innernodeloss = 1 - hstrat_aux.alifestd_count_inner_nodes(\n        hstrat_aux.alifestd_collapse_unifurcations(tree.as_alife),\n    ) / hstrat_aux.alifestd_count_inner_nodes(\n        hstrat_aux.alifestd_collapse_unifurcations(true_phylogeny_df),\n    )\n    ax.set_xlim(0, 1)\n    ax.set_ylim(-0.2, 1)\n    ax.axhline(y=0, color="black", linewidth=1)\n    ax.grid(axis="y")\n    ax.scatter(\n        [0.33],\n        [tripdist],\n        color=["purple"],\n        marker="o",\n        clip_on=False,\n        s=80,\n        zorder=10,\n    )\n    ax.scatter(\n        [0.66],\n        [innernodeloss],\n        color=["green"],\n        marker="v",\n        clip_on=False,\n        s=80,\n        zorder=10,\n    )\n\n\n# Adjust layout\nplt.subplots_adjust(bottom=0.05, top=0.86)\n\nfig.suptitle("policy = steady (column)", size="xx-large")\nos.makedirs("outplots", exist_ok=True)\nplt.savefig(\n    "outplots/a=examplepanel+policy=col-steady+regime=plain+ext= ...
#   'import datetime\n\ndatetime.datetime.now().isoformat()',
#   "get_ipython().run_line_magic('load_ext', 'watermark')\nget_ipython().run_line_magic('watermark', '')",
#   'locals()'],
#  'Out': {2: 1, 11: '2024-10-02T04:02:38.405389'},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7fcfe5c72aa0>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x7fcfe5c73580>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x7fcfe5c73580>,
#  'open': <function io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>,
#  '_': '2024-10-02T04:02:38.405389',
#  '__': 1,
#  '___': '',
#  '_i': '%load_ext watermark\n%watermark',
#  '_ii': 'import datetime\n\ndatetime.datetime.now().isoformat()',
#  '_iii': 'trees = [\n    make_reconstructed_rosettatree(\n        "col-steady",\n        annotation_size_bits=32,\n        differentia_width_bits=1,\n        true_phylogeny_df=true_phylogeny_df,\n        num_generations=num_generations,\n    ),\n    make_reconstructed_rosettatree(\n        "col-steady",\n        annotation_size_bits=64,\n        differentia_width_bits=1,\n        true_phylogeny_df=true_phylogeny_df,\n        num_generations=num_generations,\n    ),\n    make_reconstructed_rosettatree(\n        "col-steady",\n        annotation_size_bits=256,\n        differentia_width_bits=1,\n        true_phylogeny_df=true_phylogeny_df,\n        num_generations=num_generations,\n    ),\n    make_reconstructed_rosettatree(\n        "col-steady",\n        annotation_size_bits=256,\n        differentia_width_bits=8,\n        true_phylogeny_df=true_phylogeny_df,\n        num_generations=num_generations,\n    ),\n]\nfig, (axs1, axs2) = plt.subplots(\n    2, 4, gridspec_kw={"wspace": 0, "hspace": 0.1}, height_ratios=[1, 3]\n)\nfig.set_size_inches(10, 8)\n\nplot2(apc.RosettaTree(logify_phylo(true_phylogeny_df)), trees[0], seed, axs2[0])\nplot2(apc.RosettaTree(logify_phylo(true_phylogeny_df)), trees[1], seed, axs2[1])\nplot2(apc.RosettaTree(logify_phylo(true_phylogeny_df)), trees[2], seed, axs2[2])\nplot2(apc.RosettaTree(logify_phylo(true_phylogeny_df)), trees[3], seed, axs2[3])\n\nplt.tight_layout()\nplt.subplots_adjust(wspace=0, hspace=0)\n\n# Create the legend patches\norange_patch = mpl_patches.Patch(color="orange", label="Reference")\nblue_patch = mpl_patches.Patch(color="blue", label="Reconstruction")\n\n# Create a custom legend without a frame\nlegend = fig.legend(\n    handles=[orange_patch, blue_patch],\n    loc="lower center",\n    ncol=2,\n    frameon=False,\n)\n\naxs1[0].set_title("32-bit size\\nbit differentia")\naxs1[1].set_title("64-bit size,\\nbit differentia")\naxs1[2].set_title("256-bit size\\nbit differentia")\naxs1[3].set_title("256-bit size\\nbyte differentia")\n# Remove axes borders except for bottom, and remove y-axis tick/labels\nfor i, ax in enumerate(axs1):\n    ax.axes.get_xaxis().set_visible(True)\n    ax.axes.get_yaxis().set_visible(True)\n    ax.set_xticks([0.33, 0.66])\n    ax.set_xticklabels(["T. Dist.", "I.N. Loss"])\n    ax.spines["top"].set_visible(False)\n    ax.spines["bottom"].set_visible(True)\n    ax.spines["right"].set_visible(False)\n    ax.spines["left"].set_visible(True)\n    if i:\n        ax.set_yticklabels([])\n\nfor tree, ax in zip(trees, axs1):\n    tripdist = calc_tqdist_distance(true_phylogeny_df, tree.as_alife)[\n        "triplet_distance"\n    ]\n    # tripdist = hstrat_aux.alifestd_estimate_triplet_distance_asexual(\n    #     hstrat_aux.alifestd_collapse_unifurcations(true_phylogeny_df),\n    #     hstrat_aux.alifestd_collapse_unifurcations(tree.as_alife),\n    #     taxon_label_key="taxon_label",\n    #     strict=True,\n    #     progress_wrap=tqdm,\n    #     mutate=False,\n    #     confidence=0.9,\n    #     precision=0.05,\n    # )\n    innernodeloss = 1 - hstrat_aux.alifestd_count_inner_nodes(\n        hstrat_aux.alifestd_collapse_unifurcations(tree.as_alife),\n    ) / hstrat_aux.alifestd_count_inner_nodes(\n        hstrat_aux.alifestd_collapse_unifurcations(true_phylogeny_df),\n    )\n    ax.set_xlim(0, 1)\n    ax.set_ylim(-0.2, 1)\n    ax.axhline(y=0, color="black", linewidth=1)\n    ax.grid(axis="y")\n    ax.scatter(\n        [0.33],\n        [tripdist],\n        color=["purple"],\n        marker="o",\n        clip_on=False,\n        s=80,\n        zorder=10,\n    )\n    ax.scatter(\n        [0.66],\n        [innernodeloss],\n        color=["green"],\n        marker="v",\n        clip_on=False,\n        s=80,\n        zorder=10,\n    )\n\n\n# Adjust layout\nplt.subplots_adjust(bottom=0.05, top=0.86)\n\nfig.suptitle("policy = steady (column)", size="xx-large")\nos.makedirs("outplots", exist_ok=True)\nplt.savefig(\n    "outplots/a=examplepanel+policy=col-steady+regime=pla ...
#  '_i1': 'import os\nimport typing\nimport uuid\n\nimport alifedata_phyloinformatics_convert as apc\nfrom Bio import Phylo\nfrom colorclade._biopython_sort_tree import biopython_sort_tree\nfrom hstrat import hstrat\nfrom hstrat import _auxiliary_lib as hstrat_aux\nfrom hsurf import hsurf\nfrom matplotlib import pyplot as plt\nfrom matplotlib import patches as mpl_patches\nimport numpy as np\nimport pandas as pd\nimport tqdist\nfrom tqdm.notebook import tqdm',
#  'os': <module 'os' from '/usr/lib/python3.10/os.py'>,
#  'typing': <module 'typing' from '/usr/lib/python3.10/typing.py'>,
#  'uuid': <module 'uuid' from '/usr/lib/python3.10/uuid.py'>,
#  'apc': <module 'alifedata_phyloinformatics_convert' from '/home/runner/.local/lib/python3.10/site-packages/alifedata_phyloinformatics_convert/__init__.py'>,
#  'Phylo': <module 'Bio.Phylo' from '/home/runner/.local/lib/python3.10/site-packages/Bio/Phylo/__init__.py'>,
#  'biopython_sort_tree': <function colorclade._biopython_sort_tree.biopython_sort_tree(tree: <module 'Bio.Phylo.BaseTree' from '/home/runner/.local/lib/python3.10/site-packages/Bio/Phylo/BaseTree.py'>) -> None>,
#  'hstrat': <module 'hstrat.hstrat' from '/home/runner/.local/lib/python3.10/site-packages/hstrat/hstrat/__init__.py'>,
#  'hstrat_aux': <module 'hstrat._auxiliary_lib' from '/home/runner/.local/lib/python3.10/site-packages/hstrat/_auxiliary_lib/__init__.py'>,
#  'hsurf': <module 'hsurf.hsurf' from '/home/runner/.local/lib/python3.10/site-packages/hsurf/hsurf/__init__.py'>,
#  'plt': <module 'matplotlib.pyplot' from '/home/runner/.local/lib/python3.10/site-packages/matplotlib/pyplot.py'>,
#  'mpl_patches': <module 'matplotlib.patches' from '/home/runner/.local/lib/python3.10/site-packages/matplotlib/patches.py'>,
#  'np': <module 'numpy' from '/home/runner/.local/lib/python3.10/site-packages/numpy/__init__.py'>,
#  'pd': <module 'pandas' from '/home/runner/.local/lib/python3.10/site-packages/pandas/__init__.py'>,
#  'tqdist': <module 'tqdist' from '/home/runner/.local/lib/python3.10/site-packages/tqdist.cpython-310-x86_64-linux-gnu.so'>,
#  'tqdm': tqdm.notebook.tqdm_notebook,
#  '_i2': 'seed = 1\n\nseed',
#  'seed': 1,
#  '_2': 1,
#  '_i3': 'from hstrat._auxiliary_lib import seed_random\n\nseed_random(seed)',
#  'seed_random': <function hstrat._auxiliary_lib.seed_random(seed: int) -> bool>,
#  '_i4': 'from pylib._phyloviz import (\n    logify_phylo,\n    make_policy,\n    make_reconstructed_rosettatree,\n    prune_100,\n    plot2,\n    calc_tqdist_distance,\n)',
#  'logify_phylo': <function pylib._phyloviz.logify_phylo(phylo_df)>,
#  'make_policy': <function pylib._phyloviz.make_policy(stratum_retention_algo, annotation_size_bits, differentia_width_bits, num_generations)>,
#  'make_reconstructed_rosettatree': <function pylib._phyloviz.make_reconstructed_rosettatree(stratum_retention_algo, annotation_size_bits, differentia_width_bits, true_phylogeny_df, num_generations)>,
#  'prune_100': <function pylib._phyloviz.prune_100(tree, seed)>,
#  'plot2': <function pylib._phyloviz.plot2(tree_a, tree_b, seed, ax=None)>,
#  'calc_tqdist_distance': <function pylib._phyloviz.calc_tqdist_distance(x: pandas.core.frame.DataFrame, y: pandas.core.frame.DataFrame, progress_wrap: Callable = <function <lambda> at 0x7fcf8e03d630>) -> float>,
#  '_i5': 'num_generations = 100000',
#  'num_generations': 100000,
#  '_i6': 'true_phylogeny_df = pd.read_parquet("https://osf.io/zbwme/download")',
#  'true_phylogeny_df':       id ancestor_list    loc          trait  origin_time  island  niche  \
#  0      0        [none]      0            NaN            0       0      0
#  1      1           [0]   9472  113975.960938        99787       0      0
#  2      2           [1]  54467  113985.234375        99792       0      0
#  3      3           [2]  59063  113986.531250        99793       0      0
#  4      4           [3]  64163  114085.757812        99881       0      0
#  ..   ...           ...    ...            ...          ...     ...    ...
#  945  945         [215]  64717  114212.812500       100001       0      0
#  946  946          [84]  64841  114214.781250       100001       0      0
#  947  947         [416]  64875  114215.906250       100001       0      0
#  948  948         [383]  64926  114216.601562       100001       0      0
#  949  949         [442]  65280  114215.835938       100001       0      0
#
#      taxon_label  is_leaf  ancestor_id  extant
#  0                  False            0   False
#  1                  False            0   False
#  2                  False            1   False
#  3                  False            2   False
#  4                  False            3   False
#  ..          ...      ...          ...     ...
#  945       64717     True          215    True
#  946       64841     True           84    True
#  947       64875     True          416    True
#  948       64926     True          383    True
#  949       65280     True          442    True
#
#  [950 rows x 11 columns],
#  '_i7': 'full_true_phylogeny_df = true_phylogeny_df.copy()',
#  'full_true_phylogeny_df':       id ancestor_list    loc          trait  origin_time  island  niche  \
#  0      0        [none]      0            NaN            0       0      0
#  1      1           [0]   9472  113975.960938        99787       0      0
#  2      2           [1]  54467  113985.234375        99792       0      0
#  3      3           [2]  59063  113986.531250        99793       0      0
#  4      4           [3]  64163  114085.757812        99881       0      0
#  ..   ...           ...    ...            ...          ...     ...    ...
#  945  945         [215]  64717  114212.812500       100001       0      0
#  946  946          [84]  64841  114214.781250       100001       0      0
#  947  947         [416]  64875  114215.906250       100001       0      0
#  948  948         [383]  64926  114216.601562       100001       0      0
#  949  949         [442]  65280  114215.835938       100001       0      0
#
#      taxon_label  is_leaf  ancestor_id  extant
#  0                  False            0   False
#  1                  False            0   False
#  2                  False            1   False
#  3                  False            2   False
#  4                  False            3   False
#  ..          ...      ...          ...     ...
#  945       64717     True          215    True
#  946       64841     True           84    True
#  947       64875     True          416    True
#  948       64926     True          383    True
#  949       65280     True          442    True
#
#  [950 rows x 11 columns],
#  '_i8': 'downsample = 500\nprint(f"{downsample=}")\nif downsample:\n    print(f"downsampling to {downsample=}")\n    leaf_ids = hstrat_aux.alifestd_find_leaf_ids(true_phylogeny_df)\n    downsample_ids = np.random.default_rng(seed).choice(\n        leaf_ids,\n        downsample,\n        replace=False,\n    )\n    true_phylogeny_df["extant"] = False\n    true_phylogeny_df.loc[\n        true_phylogeny_df["id"].isin(downsample_ids),\n        "extant",\n    ] = True\n    true_phylogeny_df = hstrat_aux.alifestd_prune_extinct_lineages_asexual(\n        true_phylogeny_df,\n        mutate=True,\n    )\n    assert (\n        len(hstrat_aux.alifestd_find_leaf_ids(true_phylogeny_df)) == downsample\n    )\n\n    true_phylogeny_df = hstrat_aux.alifestd_collapse_unifurcations(\n        true_phylogeny_df,\n        mutate=True,\n    )\n    true_phylogeny_df = hstrat_aux.alifestd_to_working_format(\n        true_phylogeny_df,\n        mutate=True,\n    ).reset_index(drop=True)',
#  'downsample': 500,
#  'leaf_ids': [450,
#   451,
#   452,
#   453,
#   454,
#   455,
#   456,
#   457,
#   458,
#   459,
#   460,
#   461,
#   462,
#   463,
#   464,
#   465,
#   466,
#   467,
#   468,
#   469,
#   470,
#   471,
#   472,
#   473,
#   474,
#   475,
#   476,
#   477,
#   478,
#   479,
#   480,
#   481,
#   482,
#   483,
#   484,
#   485,
#   486,
#   487,
#   488,
#   489,
#   490,
#   491,
#   492,
#   493,
#   494,
#   495,
#   496,
#   497,
#   498,
#   499,
#   500,
#   501,
#   502,
#   503,
#   504,
#   505,
#   506,
#   507,
#   508,
#   509,
#   510,
#   511,
#   512,
#   513,
#   514,
#   515,
#   516,
#   517,
#   518,
#   519,
#   520,
#   521,
#   522,
#   523,
#   524,
#   525,
#   526,
#   527,
#   528,
#   529,
#   530,
#   531,
#   532,
#   533,
#   534,
#   535,
#   536,
#   537,
#   538,
#   539,
#   540,
#   541,
#   542,
#   543,
#   544,
#   545,
#   546,
#   547,
#   548,
#   549,
#   550,
#   551,
#   552,
#   553,
#   554,
#   555,
#   556,
#   557,
#   558,
#   559,
#   560,
#   561,
#   562,
#   563,
#   564,
#   565,
#   566,
#   567,
#   568,
#   569,
#   570,
#   571,
#   572,
#   573,
#   574,
#   575,
#   576,
#   577,
#   578,
#   579,
#   580,
#   581,
#   582,
#   583,
#   584,
#   585,
#   586,
#   587,
#   588,
#   589,
#   590,
#   591,
#   592,
#   593,
#   594,
#   595,
#   596,
#   597,
#   598,
#   599,
#   600,
#   601,
#   602,
#   603,
#   604,
#   605,
#   606,
#   607,
#   608,
#   609,
#   610,
#   611,
#   612,
#   613,
#   614,
#   615,
#   616,
#   617,
#   618,
#   619,
#   620,
#   621,
#   622,
#   623,
#   624,
#   625,
#   626,
#   627,
#   628,
#   629,
#   630,
#   631,
#   632,
#   633,
#   634,
#   635,
#   636,
#   637,
#   638,
#   639,
#   640,
#   641,
#   642,
#   643,
#   644,
#   645,
#   646,
#   647,
#   648,
#   649,
#   650,
#   651,
#   652,
#   653,
#   654,
#   655,
#   656,
#   657,
#   658,
#   659,
#   660,
#   661,
#   662,
#   663,
#   664,
#   665,
#   666,
#   667,
#   668,
#   669,
#   670,
#   671,
#   672,
#   673,
#   674,
#   675,
#   676,
#   677,
#   678,
#   679,
#   680,
#   681,
#   682,
#   683,
#   684,
#   685,
#   686,
#   687,
#   688,
#   689,
#   690,
#   691,
#   692,
#   693,
#   694,
#   695,
#   696,
#   697,
#   698,
#   699,
#   700,
#   701,
#   702,
#   703,
#   704,
#   705,
#   706,
#   707,
#   708,
#   709,
#   710,
#   711,
#   712,
#   713,
#   714,
#   715,
#   716,
#   717,
#   718,
#   719,
#   720,
#   721,
#   722,
#   723,
#   724,
#   725,
#   726,
#   727,
#   728,
#   729,
#   730,
#   731,
#   732,
#   733,
#   734,
#   735,
#   736,
#   737,
#   738,
#   739,
#   740,
#   741,
#   742,
#   743,
#   744,
#   745,
#   746,
#   747,
#   748,
#   749,
#   750,
#   751,
#   752,
#   753,
#   754,
#   755,
#   756,
#   757,
#   758,
#   759,
#   760,
#   761,
#   762,
#   763,
#   764,
#   765,
#   766,
#   767,
#   768,
#   769,
#   770,
#   771,
#   772,
#   773,
#   774,
#   775,
#   776,
#   777,
#   778,
#   779,
#   780,
#   781,
#   782,
#   783,
#   784,
#   785,
#   786,
#   787,
#   788,
#   789,
#   790,
#   791,
#   792,
#   793,
#   794,
#   795,
#   796,
#   797,
#   798,
#   799,
#   800,
#   801,
#   802,
#   803,
#   804,
#   805,
#   806,
#   807,
#   808,
#   809,
#   810,
#   811,
#   812,
#   813,
#   814,
#   815,
#   816,
#   817,
#   818,
#   819,
#   820,
#   821,
#   822,
#   823,
#   824,
#   825,
#   826,
#   827,
#   828,
#   829,
#   830,
#   831,
#   832,
#   833,
#   834,
#   835,
#   836,
#   837,
#   838,
#   839,
#   840,
#   841,
#   842,
#   843,
#   844,
#   845,
#   846,
#   847,
#   848,
#   849,
#   850,
#   851,
#   852,
#   853,
#   854,
#   855,
#   856,
#   857,
#   858,
#   859,
#   860,
#   861,
#   862,
#   863,
#   864,
#   865,
#   866,
#   867,
#   868,
#   869,
#   870,
#   871,
#   872,
#   873,
#   874,
#   875,
#   876,
#   877,
#   878,
#   879,
#   880,
#   881,
#   882,
#   883,
#   884,
#   885,
#   886,
#   887,
#   888,
#   889,
#   890,
#   891,
#   892,
#   893,
#   894,
#   895,
#   896,
#   897,
#   898,
#   899,
#   900,
#   901,
#   902,
#   903,
#   904,
#   905,
#   906,
#   907,
#   908,
#   909,
#   910,
#   911,
#   912,
#   913,
#   914,
#   915,
#   916,
#   917,
#   918,
#   919,
#   920,
#   921,
#   922,
#   923,
#   924,
#   925,
#   926,
#   927,
#   928,
#   929,
#   930,
#   931,
#   932,
#   933,
#   934,
#   935,
#   936,
#   937,
#   938,
#   939,
#   940,
#   941,
#   942,
#   943,
#   944,
#   945,
#   946,
#   947,
#   948,
#   949],
#  'downsample_ids': array([620, 701, 713, 739, 461, 846, 925, 723, 475, 834, 908, 949, 451,
#         580, 806, 633, 813, 520, 529, 546, 647, 733, 573, 570, 779, 594,
#         650, 631, 702, 540, 502, 822, 484, 865, 762, 679, 743, 642, 508,
#         577, 942, 651, 870, 708, 550, 859, 910, 635, 749, 764, 684, 773,
#         467, 632, 727, 803, 938, 599, 875, 763, 655, 861, 487, 678, 455,
#         552, 828, 498, 706, 939, 542, 564, 458, 829, 517, 722, 656, 593,
#         878, 571, 770, 801, 820, 606, 876, 613, 858, 710, 703, 866, 482,
#         604, 789, 784, 618, 658, 729, 624, 636, 824, 530, 675, 586, 653,
#         931, 745, 909, 611, 851, 528, 923, 664, 893, 674, 941, 873, 717,
#         698, 880, 497, 738, 692, 469, 928, 947, 559, 862, 686, 765, 652,
#         452, 555, 856, 857, 453, 689, 583, 827, 646, 830, 757, 912, 536,
#         694, 901, 488, 522, 761, 810, 718, 915, 607, 839, 705, 519, 867,
#         527, 735, 907, 457, 758, 746, 782, 831, 531, 771, 841, 804, 837,
#         465, 544, 926, 740, 697, 567, 479, 816, 623, 768, 513, 791, 523,
#         483, 680, 630, 712, 930, 885, 579, 783, 695, 808, 641, 750, 612,
#         899, 670, 637, 454, 507, 754, 884, 533, 932, 902, 691, 809, 906,
#         576, 704, 644, 742, 609, 744, 574, 588, 879, 553, 485, 472, 728,
#         812, 887, 587, 515, 537, 616, 558, 598, 495, 818, 677, 456, 864,
#         592, 672, 886, 940, 668, 929, 799, 860, 462, 772, 767, 794, 700,
#         556, 793, 585, 690, 539, 802, 786, 826, 622, 711, 548, 696, 753,
#         948, 565, 509, 566, 869, 492, 569, 628, 780, 699, 494, 877, 534,
#         946, 917, 872, 608, 835, 737, 921, 842, 734, 825, 905, 590, 557,
#         657, 589, 778, 790, 751, 781, 900, 601, 747, 777, 731, 532, 721,
#         914, 575, 514, 725, 788, 855, 596, 800, 610, 562, 903, 503, 807,
#         888, 511, 792, 648, 891, 506, 707, 881, 563, 850, 685, 491, 883,
#         693, 568, 920, 584, 821, 496, 538, 913, 719, 561, 844, 730, 541,
#         614, 895, 500, 796, 581, 945, 480, 927, 848, 470, 854, 916, 549,
#         450, 933, 832, 688, 889, 776, 525, 922, 468, 524, 473, 505, 943,
#         521, 687, 621, 911, 756, 597, 639, 543, 602, 681, 665, 660, 815,
#         595, 661, 471, 843, 769, 817, 934, 547, 823, 629, 673, 759, 615,
#         582, 874, 766, 669, 643, 667, 627, 560, 811, 892, 709, 476, 619,
#         755, 852, 591, 897, 836, 840, 714, 617, 847, 551, 477, 640, 894,
#         774, 518, 814, 741, 666, 732, 944, 919, 645, 785, 833, 795, 715,
#         463, 504, 716, 682, 724, 748, 490, 868, 654, 853, 499, 924, 501,
#         890, 726, 935, 863, 849, 486, 736, 937, 904, 845, 663, 603, 659,
#         626, 512, 510, 898, 605, 797, 798, 918, 896, 683, 493, 578, 478,
#         819, 838, 720, 460, 760, 600, 936, 871, 882, 671, 474, 649, 634,
#         554, 545, 489, 625, 459, 516, 638, 572, 526, 535, 787, 805, 662,
#         464, 466, 676, 752, 481, 775]),
#  '_i9': 'trees = [\n    make_reconstructed_rosettatree(\n        "surf-tilted",\n        annotation_size_bits=32,\n        differentia_width_bits=1,\n        true_phylogeny_df=true_phylogeny_df,\n        num_generations=num_generations,\n    ),\n    make_reconstructed_rosettatree(\n        "surf-tilted",\n        annotation_size_bits=64,\n        differentia_width_bits=1,\n        true_phylogeny_df=true_phylogeny_df,\n        num_generations=num_generations,\n    ),\n    make_reconstructed_rosettatree(\n        "surf-tilted",\n        annotation_size_bits=256,\n        differentia_width_bits=1,\n        true_phylogeny_df=true_phylogeny_df,\n        num_generations=num_generations,\n    ),\n    make_reconstructed_rosettatree(\n        "surf-tilted",\n        annotation_size_bits=256,\n        differentia_width_bits=8,\n        true_phylogeny_df=true_phylogeny_df,\n        num_generations=num_generations,\n    ),\n]\nfig, (axs1, axs2) = plt.subplots(\n    2, 4, gridspec_kw={"wspace": 0, "hspace": 0.1}, height_ratios=[1, 3]\n)\nfig.set_size_inches(10, 8)\n\nplot2(apc.RosettaTree(logify_phylo(true_phylogeny_df)), trees[0], seed, axs2[0])\nplot2(apc.RosettaTree(logify_phylo(true_phylogeny_df)), trees[1], seed, axs2[1])\nplot2(apc.RosettaTree(logify_phylo(true_phylogeny_df)), trees[2], seed, axs2[2])\nplot2(apc.RosettaTree(logify_phylo(true_phylogeny_df)), trees[3], seed, axs2[3])\n\nplt.tight_layout()\nplt.subplots_adjust(wspace=0, hspace=0)\n\n# Create the legend patches\norange_patch = mpl_patches.Patch(color="orange", label="Reference")\nblue_patch = mpl_patches.Patch(color="blue", label="Reconstruction")\n\n# Create a custom legend without a frame\nlegend = fig.legend(\n    handles=[orange_patch, blue_patch],\n    loc="lower center",\n    ncol=2,\n    frameon=False,\n)\n\naxs1[0].set_title("32-bit size\\nbit differentia")\naxs1[1].set_title("64-bit size,\\nbit differentia")\naxs1[2].set_title("256-bit size\\nbit differentia")\naxs1[3].set_title("256-bit size\\nbyte differentia")\n# Remove axes borders except for bottom, and remove y-axis tick/labels\nfor i, ax in enumerate(axs1):\n    ax.axes.get_xaxis().set_visible(True)\n    ax.axes.get_yaxis().set_visible(True)\n    ax.set_xticks([0.33, 0.66])\n    ax.set_xticklabels(["T. Dist.", "I.N. Loss"])\n    ax.spines["top"].set_visible(False)\n    ax.spines["bottom"].set_visible(True)\n    ax.spines["right"].set_visible(False)\n    ax.spines["left"].set_visible(True)\n    if i:\n        ax.set_yticklabels([])\n\nfor tree, ax in zip(trees, axs1):\n    tripdist = calc_tqdist_distance(true_phylogeny_df, tree.as_alife)[\n        "triplet_distance"\n    ]\n    # tripdist = hstrat_aux.alifestd_estimate_triplet_distance_asexual(\n    #     hstrat_aux.alifestd_collapse_unifurcations(true_phylogeny_df),\n    #     hstrat_aux.alifestd_collapse_unifurcations(tree.as_alife),\n    #     taxon_label_key="taxon_label",\n    #     strict=True,\n    #     progress_wrap=tqdm,\n    #     mutate=False,\n    #     confidence=0.9,\n    #     precision=0.05,\n    # )\n    innernodeloss = 1 - hstrat_aux.alifestd_count_inner_nodes(\n        hstrat_aux.alifestd_collapse_unifurcations(tree.as_alife),\n    ) / hstrat_aux.alifestd_count_inner_nodes(\n        hstrat_aux.alifestd_collapse_unifurcations(true_phylogeny_df),\n    )\n    ax.set_xlim(0, 1)\n    ax.set_ylim(-0.2, 1)\n    ax.axhline(y=0, color="black", linewidth=1)\n    ax.grid(axis="y")\n    ax.scatter(\n        [0.33],\n        [tripdist],\n        color=["purple"],\n        marker="o",\n        clip_on=False,\n        s=80,\n        zorder=10,\n    )\n    ax.scatter(\n        [0.66],\n        [innernodeloss],\n        color=["green"],\n        marker="v",\n        clip_on=False,\n        s=80,\n        zorder=10,\n    )\n\n\n# Adjust layout\nplt.subplots_adjust(bottom=0.05, top=0.86)\n\nfig.suptitle("policy = tilted (surface)", size="xx-large")\nos.makedirs("outplots", exist_ok=True)\nplt.savefig(\n    "outplots/a=examplepanel+policy=surf-tilted+regim ...
#  'trees': [<alifedata_phyloinformatics_convert.RosettaTree.RosettaTree at 0x7fcf64bfaec0>,
#   <alifedata_phyloinformatics_convert.RosettaTree.RosettaTree at 0x7fcf65be7a60>,
#   <alifedata_phyloinformatics_convert.RosettaTree.RosettaTree at 0x7fcf65b04bb0>,
#   <alifedata_phyloinformatics_convert.RosettaTree.RosettaTree at 0x7fcf65a7c0a0>],
#  'fig': <Figure size 1000x800 with 8 Axes>,
#  'axs1': array([<Axes: title={'center': '32-bit size\nbit differentia'}>,
#         <Axes: title={'center': '64-bit size,\nbit differentia'}>,
#         <Axes: title={'center': '256-bit size\nbit differentia'}>,
#         <Axes: title={'center': '256-bit size\nbyte differentia'}>],
#        dtype=object),
#  'axs2': array([<Axes: xlabel='branch length', ylabel='taxa'>,
#         <Axes: xlabel='branch length', ylabel='taxa'>,
#         <Axes: xlabel='branch length', ylabel='taxa'>,
#         <Axes: xlabel='branch length', ylabel='taxa'>], dtype=object),
#  'orange_patch': <matplotlib.patches.Patch at 0x7fcf659b4220>,
#  'blue_patch': <matplotlib.patches.Patch at 0x7fcf659dd000>,
#  'legend': <matplotlib.legend.Legend at 0x7fcf7c3543a0>,
#  'i': 3,
#  'ax': <Axes: title={'center': '256-bit size\nbyte differentia'}>,
#  'tree': <alifedata_phyloinformatics_convert.RosettaTree.RosettaTree at 0x7fcf65a7c0a0>,
#  'tripdist': 0.9991085303136393,
#  'innernodeloss': 0.9955555555555555,
#  '_i10': 'trees = [\n    make_reconstructed_rosettatree(\n        "col-steady",\n        annotation_size_bits=32,\n        differentia_width_bits=1,\n        true_phylogeny_df=true_phylogeny_df,\n        num_generations=num_generations,\n    ),\n    make_reconstructed_rosettatree(\n        "col-steady",\n        annotation_size_bits=64,\n        differentia_width_bits=1,\n        true_phylogeny_df=true_phylogeny_df,\n        num_generations=num_generations,\n    ),\n    make_reconstructed_rosettatree(\n        "col-steady",\n        annotation_size_bits=256,\n        differentia_width_bits=1,\n        true_phylogeny_df=true_phylogeny_df,\n        num_generations=num_generations,\n    ),\n    make_reconstructed_rosettatree(\n        "col-steady",\n        annotation_size_bits=256,\n        differentia_width_bits=8,\n        true_phylogeny_df=true_phylogeny_df,\n        num_generations=num_generations,\n    ),\n]\nfig, (axs1, axs2) = plt.subplots(\n    2, 4, gridspec_kw={"wspace": 0, "hspace": 0.1}, height_ratios=[1, 3]\n)\nfig.set_size_inches(10, 8)\n\nplot2(apc.RosettaTree(logify_phylo(true_phylogeny_df)), trees[0], seed, axs2[0])\nplot2(apc.RosettaTree(logify_phylo(true_phylogeny_df)), trees[1], seed, axs2[1])\nplot2(apc.RosettaTree(logify_phylo(true_phylogeny_df)), trees[2], seed, axs2[2])\nplot2(apc.RosettaTree(logify_phylo(true_phylogeny_df)), trees[3], seed, axs2[3])\n\nplt.tight_layout()\nplt.subplots_adjust(wspace=0, hspace=0)\n\n# Create the legend patches\norange_patch = mpl_patches.Patch(color="orange", label="Reference")\nblue_patch = mpl_patches.Patch(color="blue", label="Reconstruction")\n\n# Create a custom legend without a frame\nlegend = fig.legend(\n    handles=[orange_patch, blue_patch],\n    loc="lower center",\n    ncol=2,\n    frameon=False,\n)\n\naxs1[0].set_title("32-bit size\\nbit differentia")\naxs1[1].set_title("64-bit size,\\nbit differentia")\naxs1[2].set_title("256-bit size\\nbit differentia")\naxs1[3].set_title("256-bit size\\nbyte differentia")\n# Remove axes borders except for bottom, and remove y-axis tick/labels\nfor i, ax in enumerate(axs1):\n    ax.axes.get_xaxis().set_visible(True)\n    ax.axes.get_yaxis().set_visible(True)\n    ax.set_xticks([0.33, 0.66])\n    ax.set_xticklabels(["T. Dist.", "I.N. Loss"])\n    ax.spines["top"].set_visible(False)\n    ax.spines["bottom"].set_visible(True)\n    ax.spines["right"].set_visible(False)\n    ax.spines["left"].set_visible(True)\n    if i:\n        ax.set_yticklabels([])\n\nfor tree, ax in zip(trees, axs1):\n    tripdist = calc_tqdist_distance(true_phylogeny_df, tree.as_alife)[\n        "triplet_distance"\n    ]\n    # tripdist = hstrat_aux.alifestd_estimate_triplet_distance_asexual(\n    #     hstrat_aux.alifestd_collapse_unifurcations(true_phylogeny_df),\n    #     hstrat_aux.alifestd_collapse_unifurcations(tree.as_alife),\n    #     taxon_label_key="taxon_label",\n    #     strict=True,\n    #     progress_wrap=tqdm,\n    #     mutate=False,\n    #     confidence=0.9,\n    #     precision=0.05,\n    # )\n    innernodeloss = 1 - hstrat_aux.alifestd_count_inner_nodes(\n        hstrat_aux.alifestd_collapse_unifurcations(tree.as_alife),\n    ) / hstrat_aux.alifestd_count_inner_nodes(\n        hstrat_aux.alifestd_collapse_unifurcations(true_phylogeny_df),\n    )\n    ax.set_xlim(0, 1)\n    ax.set_ylim(-0.2, 1)\n    ax.axhline(y=0, color="black", linewidth=1)\n    ax.grid(axis="y")\n    ax.scatter(\n        [0.33],\n        [tripdist],\n        color=["purple"],\n        marker="o",\n        clip_on=False,\n        s=80,\n        zorder=10,\n    )\n    ax.scatter(\n        [0.66],\n        [innernodeloss],\n        color=["green"],\n        marker="v",\n        clip_on=False,\n        s=80,\n        zorder=10,\n    )\n\n\n# Adjust layout\nplt.subplots_adjust(bottom=0.05, top=0.86)\n\nfig.suptitle("policy = steady (column)", size="xx-large")\nos.makedirs("outplots", exist_ok=True)\nplt.savefig(\n    "outplots/a=examplepanel+policy=col-steady+regime=pla ...
#  '_i11': 'import datetime\n\ndatetime.datetime.now().isoformat()',
#  'datetime': <module 'datetime' from '/usr/lib/python3.10/datetime.py'>,
#  '_11': '2024-10-02T04:02:38.405389',
#  '_i12': '%load_ext watermark\n%watermark',
#  '_i13': 'locals()'}
